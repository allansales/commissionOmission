# %%
import numpy as np
import pandas as pd
from gensim.models import Word2Vec
from gensim.models import KeyedVectors

# %%
model = KeyedVectors.load_word2vec_format('word_embeddings/model.bin', binary=True)

# %%
args_json = pd.read_json("../crawlers/procon/procon.json")
wiki_json = pd.read_json("../crawlers/procon/wiki.json")

# %% [markdown]
# #### Format DataFrame rows

# %%
def format_args_row(row):
    df = row.apply(pd.Series).T
    df.url = df.url[0]
    df.topic = df.topic[0]
    return(df)

arg_df_series = args_json.apply(format_args_row, axis=1)
args_df = pd.concat(arg_df_series.values.tolist(),ignore_index=True)

# %%
def format_wiki_row(row):
    df = row.apply(pd.Series).T
    df.source = df.source[0]
    df.title = df.title[0]
    df.topic = df.topic[0]
    df.stance = df.stance[0]
    return(df)

wiki_df_series = wiki_json.apply(format_wiki_row, axis=1)
wiki_df = pd.concat(wiki_df_series.values.tolist(),ignore_index=True)

# %%
wiki_df
# Out:
#              source          topic stance               title  \
# 0     conservapedia  Death Penalty    Pro  Capital punishment
# 1     conservapedia  Death Penalty    Pro  Capital punishment
# 2     conservapedia  Death Penalty    Pro  Capital punishment
# 3     conservapedia  Death Penalty    Pro  Capital punishment
# 4     conservapedia  Death Penalty    Pro  Capital punishment
# ...             ...            ...    ...                 ...
# 4694  conservapedia       Iraq War    Pro            Iraq War
# 4695  conservapedia       Iraq War    Pro            Iraq War
# 4696  conservapedia       Iraq War    Pro            Iraq War
# 4697  conservapedia       Iraq War    Pro            Iraq War
# 4698  conservapedia       Iraq War    Pro            Iraq War
#
#                                                 content
# 0     Capital punishment, also known as the death pe...
# 1     There are several compelling justifications fo...
# 2     Opposition to the death penalty ignores its fo...
# 3     Although support for the death penalty has lar...
# 4                                              Contents
# ...                                                 ...
# 4694  America destroyed Iraq but the war crimes rema...
# 4695  "Despite the failures that occurred in the tim...
# 4696
# 4697  Her dissatisfaction with politicians is only n...
# 4698  Less than 40 per cent of Iraqi adults have a j...
#
# [4699 rows x 5 columns]

# %% [markdown]
# ### Preprocess Text

# %% [markdown]
# #### Create dataframe which will store the data

# %%
wmd_df = args_df.merge(wiki_df)

# %% [markdown]
# #### Lowercase and remove Stopwords

# %%
from nltk.corpus import stopwords
from nltk import download
download('stopwords') 

stop_words = stopwords.words('english')

def preprocess_sentence(str_array):
    new_sentences = []
    sentences_size = []
    for text in str_array:
        new_sentence = ""
        for word in text.split():
            if word not in stop_words:
                new_sentence += " " + word.lower()
        sentences_size.append(new_sentence.count(" "))
        new_sentences.append(new_sentence.strip())
        
    return(new_sentences, sentences_size)
# Out:
# [nltk_data] Downloading package stopwords to /home/allan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
wmd_df['argument_processed'], wmd_df['argument_processed_size']  = preprocess_sentence(wmd_df.argument)
wmd_df['paragraph_processed'], wmd_df['paragraph_processed_size'] = preprocess_sentence(wmd_df.content)

# %%
#wmd_df = wmd_df.assign(argument_processed = preprocess_sentence(wmd_df.argument),
#                      content_processed = preprocess_sentence(wmd_df.content))

# %% [markdown]
# #### Add argument orientation

# %%
def orientation(pro_con):
    if "Pro" in pro_con:
        return "Pro"
    return "Con"

wmd_df = wmd_df.assign(arg_orient = wmd_df.apply(lambda row: orientation(row.pro_con), axis=1))

# %% [markdown]
# #### Remove rows which either the content_processed or argument_processed is too short
#
# Our goal is computing the similarity between an idea (paragraph) and an argument. However, some rows contain only a few words (sometimes only one word), which are not enough for expressing one idea. Thus, we define a variable for determining the minimum size of a paragraph.

# %%
paragraph_min_size = 5

wmd_df = wmd_df.query("paragraph_processed_size > " + str(paragraph_min_size)).query("argument_processed_size > " + str(paragraph_min_size))

# %% [markdown]
# #### Compute the WMD between the arguments and paragraphs

# %%
#from tqdm import tqdm
#tqdm.pandas()

#model.init_sims(replace=True)

#wmd_df['wmd'] = wmd_df.progress_apply(lambda x: model.wmdistance(x.argument_processed.split(), x.paragraph_processed.split()), axis=1)

# %% [markdown]
# #### Similarity computation

# %%
#wmd_df = wmd_df.assign(wmd_sim = (wmd_df.wmd - wmd_df.wmd.min()) / (wmd_df.wmd.max() - wmd_df.wmd.min()))

# %%
#wmd_df = wmd_df.rename(columns={"wmd_sim":"wmd_norm", "content":"paragraph", "content_processed":"paragraph_processed", "content_processed_size":"paragraph_processed_size"})

#paragraph_min_size = 15
#wmd_df = wmd_df.query("paragraph_processed_size > " + str(paragraph_min_size)).query("argument_processed_size > " + str(paragraph_min_size))

# %%
#wmd_df.to_csv('wmd_distances.csv', index = None, header=True)
wmd_df = pd.read_csv("wmd_distances.csv")
wmd_df = wmd_df.rename(columns={"wmd_sim":"wmd_norm", "stance":"source_stance"})

wmd_df = wmd_df[wmd_df.topic != "Gay Marriage"]
# Out:
# /home/allan/.local/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
wmd_df.head()
# Out:
#                                                  url       topic pro_con  \
# 0  https://euthanasia.procon.org/view.resource.ph...  Euthanasia   Pro 1
# 1  https://euthanasia.procon.org/view.resource.ph...  Euthanasia   Pro 1
# 2  https://euthanasia.procon.org/view.resource.ph...  Euthanasia   Pro 1
# 3  https://euthanasia.procon.org/view.resource.ph...  Euthanasia   Pro 1
# 4  https://euthanasia.procon.org/view.resource.ph...  Euthanasia   Pro 1
#
#   argument_topic                                           argument  \
# 0   Legalization  The right to die should be a matter of persona...
# 1   Legalization  The right to die should be a matter of persona...
# 2   Legalization  The right to die should be a matter of persona...
# 3   Legalization  The right to die should be a matter of persona...
# 4   Legalization  The right to die should be a matter of persona...
#
#   argument_summary         source source_stance       title  \
# 0              NaN  conservapedia           Con  Euthanasia
# 1              NaN  conservapedia           Con  Euthanasia
# 2              NaN  conservapedia           Con  Euthanasia
# 3              NaN  conservapedia           Con  Euthanasia
# 4              NaN  conservapedia           Con  Euthanasia
#
#                                            paragraph  \
# 0  Euthanasia Society lists Margaret Sanger as a ...
# 1  Euthanasia (from the Greek for good death) is ...
# 2  Most libertarians and many liberals support le...
# 3  The widely reported withdrawal of a feeding tu...
# 4  Of recent concern are erroneous reports (July ...
#
#                                   argument_processed  argument_processed_size  \
# 0  the right die matter personal choice. we able ...                       62
# 1  the right die matter personal choice. we able ...                       62
# 2  the right die matter personal choice. we able ...                       62
# 3  the right die matter personal choice. we able ...                       62
# 4  the right die matter personal choice. we able ...                       62
#
#                                  paragraph_processed  \
# 0    euthanasia society lists margaret sanger member
# 1  euthanasia (from greek good death) politically...
# 2  most libertarians many liberals support legali...
# 3  the widely reported withdrawal feeding tube di...
# 4  of recent concern erroneous reports (july 2009...
#
#    paragraph_processed_size arg_orient       wmd  wmd_norm
# 0                         6        Pro  1.144770  0.816794
# 1                        39        Pro  0.923911  0.509788
# 2                       126        Pro  0.897518  0.473101
# 3                        41        Pro  0.949271  0.545041
# 4                        48        Pro  1.005283  0.622900

# %% [markdown]
# #### Most similar (less distant) argument to each paragraph by document

# %%
most_sim_arg2paragraph = wmd_df.groupby(['paragraph']).wmd_norm.agg(['min']).reset_index()
most_sim_arg2paragraph = most_sim_arg2paragraph.merge(wmd_df, left_on=["paragraph","min"], right_on=["paragraph","wmd_norm"]).drop_duplicates()

# %% [markdown]
# ##### Number of paragraphs, by source and topic, most related to each orientation's argument

# %%
most_sim_arg2paragraph.groupby(["topic","source","arg_orient"]).size().to_frame('count').reset_index()
# Out:
#                   topic         source arg_orient  count
# 0              Abortion  conservapedia        Con    110
# 1              Abortion  conservapedia        Pro     87
# 2              Abortion   rationalwiki        Con     15
# 3              Abortion   rationalwiki        Pro     24
# 4        Climate Change  conservapedia        Con      5
# 5        Climate Change  conservapedia        Pro     24
# 6        Climate Change   rationalwiki        Con     60
# 7        Climate Change   rationalwiki        Pro    122
# 8   Corporal Punishment  conservapedia        Con      6
# 9   Corporal Punishment  conservapedia        Pro      3
# 10  Corporal Punishment   rationalwiki        Con     11
# 11  Corporal Punishment   rationalwiki        Pro     16
# 12        Death Penalty  conservapedia        Con     30
# 13        Death Penalty  conservapedia        Pro     38
# 14        Death Penalty   rationalwiki        Con     39
# 15        Death Penalty   rationalwiki        Pro     28
# 16           Euthanasia  conservapedia        Con     12
# 17           Euthanasia  conservapedia        Pro      5
# 18           Euthanasia   rationalwiki        Con     33
# 19           Euthanasia   rationalwiki        Pro     11
# 20                 GMOs  conservapedia        Con      3
# 21                 GMOs   rationalwiki        Con    114
# 22                 GMOs   rationalwiki        Pro     49
# 23          Gun Control  conservapedia        Con      8
# 24          Gun Control  conservapedia        Pro      6
# 25          Gun Control   rationalwiki        Con     20
# 26          Gun Control   rationalwiki        Pro     12
# 27     Health Care Form  conservapedia        Con     60
# 28     Health Care Form  conservapedia        Pro     82
# 29     Health Care Form   rationalwiki        Con     28
# 30     Health Care Form   rationalwiki        Pro     33
# 31             Iraq War  conservapedia        Con     98
# 32             Iraq War  conservapedia        Pro    121
# 33             Iraq War   rationalwiki        Con     49
# 34             Iraq War   rationalwiki        Pro     51
# 35            Marijuana  conservapedia        Con     22
# 36            Marijuana  conservapedia        Pro     10
# 37            Marijuana   rationalwiki        Con     88
# 38            Marijuana   rationalwiki        Pro     10
# 39         Minimum Wage  conservapedia        Con      8
# 40         Minimum Wage  conservapedia        Pro      8
# 41         Minimum Wage   rationalwiki        Con     16
# 42         Minimum Wage   rationalwiki        Pro     33
# 43       Net Neutrality  conservapedia        Con     12
# 44       Net Neutrality  conservapedia        Pro      9
# 45       Net Neutrality   rationalwiki        Con      8
# 46       Net Neutrality   rationalwiki        Pro      9
# 47         Prostitution  conservapedia        Con      8
# 48         Prostitution  conservapedia        Pro      4
# 49         Prostitution   rationalwiki        Con     17
# 50         Prostitution   rationalwiki        Pro     20
# 51      School Vouchers  conservapedia        Con      2
# 52      School Vouchers  conservapedia        Pro      4
# 53      School Vouchers   rationalwiki        Con     20
# 54      School Vouchers   rationalwiki        Pro      8
# 55          Video Games  conservapedia        Con     44
# 56          Video Games  conservapedia        Pro     15
# 57          Video Games   rationalwiki        Con     51
# 58          Video Games   rationalwiki        Pro     17

# %% [markdown]
# #### Most similar (less distant) paragraph to each argument

# %%
most_sim_paragraph2arg = wmd_df.groupby(['argument']).wmd_norm.agg(['min']).reset_index()
most_sim_paragraph2arg = most_sim_paragraph2arg.merge(wmd_df, left_on=["argument","min"], right_on=["argument","wmd_norm"]).drop_duplicates()
#most_sim_paragraph2arg = most_sim_paragraph2arg.rename(columns={"wmd_sim":"wmd_norm"})

# %%
most_sim_paragraph2arg = most_sim_paragraph2arg.groupby(["topic","source","arg_orient","source_stance"]).size().to_frame('count').reset_index()
most_sim_paragraph2arg
# Out:
#                   topic         source arg_orient source_stance  count
# 0              Abortion  conservapedia        Con           Con     15
# 1              Abortion  conservapedia        Pro           Con     14
# 2              Abortion   rationalwiki        Con           Pro      1
# 3              Abortion   rationalwiki        Pro           Pro      1
# 4        Climate Change  conservapedia        Con          Con-      5
# 5        Climate Change  conservapedia        Pro          Con-      2
# 6        Climate Change   rationalwiki        Con          Pro-      8
# 7        Climate Change   rationalwiki        Pro          Pro-     12
# 8   Corporal Punishment   rationalwiki        Con           Con      3
# 9   Corporal Punishment   rationalwiki        Pro           Con      3
# 10        Death Penalty  conservapedia        Con           Pro      2
# 11        Death Penalty  conservapedia        Pro           Pro      5
# 12        Death Penalty   rationalwiki        Con           Con      8
# 13        Death Penalty   rationalwiki        Pro           Con      5
# 14           Euthanasia  conservapedia        Con           Con      2
# 15           Euthanasia  conservapedia        Pro           Con      2
# 16           Euthanasia   rationalwiki        Con          Pro*      8
# 17           Euthanasia   rationalwiki        Pro          Pro*      8
# 18                 GMOs   rationalwiki        Con          Pro*      3
# 19                 GMOs   rationalwiki        Pro          Pro*      3
# 20          Gun Control  conservapedia        Con           Con      3
# 21          Gun Control   rationalwiki        Con           Pro     12
# 22          Gun Control   rationalwiki        Pro           Pro     15
# 23     Health Care Form  conservapedia        Con           Con      7
# 24     Health Care Form  conservapedia        Pro           Con      5
# 25     Health Care Form   rationalwiki        Con          Pro*      3
# 26     Health Care Form   rationalwiki        Pro          Pro*      5
# 27             Iraq War  conservapedia        Con           Pro      7
# 28             Iraq War  conservapedia        Pro           Pro      6
# 29             Iraq War   rationalwiki        Con           Con      3
# 30             Iraq War   rationalwiki        Pro           Con      4
# 31            Marijuana  conservapedia        Con           Con      7
# 32            Marijuana  conservapedia        Pro           Con     11
# 33            Marijuana   rationalwiki        Con           Pro      6
# 34            Marijuana   rationalwiki        Pro           Pro      2
# 35         Minimum Wage  conservapedia        Con           Con      5
# 36         Minimum Wage  conservapedia        Pro           Con      2
# 37         Minimum Wage   rationalwiki        Con          Pro*     10
# 38         Minimum Wage   rationalwiki        Pro          Pro*     13
# 39       Net Neutrality  conservapedia        Con           Con      2
# 40       Net Neutrality  conservapedia        Pro           Con      3
# 41       Net Neutrality   rationalwiki        Con           Pro      1
# 42         Prostitution   rationalwiki        Con          Pro*     10
# 43         Prostitution   rationalwiki        Pro          Pro*     10
# 44      School Vouchers   rationalwiki        Con          Pro*      4
# 45      School Vouchers   rationalwiki        Pro          Pro*      4
# 46          Video Games  conservapedia        Con          Con-      4
# 47          Video Games   rationalwiki        Con          Pro-     10
# 48          Video Games   rationalwiki        Pro          Pro-     11

# %% [raw]
# Instrucoes do que deve ser feito abaixo
#
# O WEAT original define os conjuntos de atributo a partir de palavras caracteristicas que representam o conceito que o conjunto quer passar.
#
# Para documentos, apenas usar argumentos pode ser um problema porque um documento target pode simplesmente usar mais palavras parecidas com um documento atributo do que outro target.
#
# TODO:
# * Testar WEAT com conjuntos de atributos com conceitos opostos mas nao necessariamente sobre os mesmos pontos (e.g., um conjunto de argumentos contra o aborto e outro a favor mas os argumentos contra e a favor nao necessariamente tocam nos mesmos pontos) - isso implica em os conjuntos atributos nao necessariamente precisarem ter o mesmo tamanho
#
# * Testar WEAT com conjuntos de atributos com conceitos opostos e tocando nos mesmos pontos (os conjuntos atributos precisam tocar necessariamente nos mesmos pontos. e.g., a discussao sobre a legalizacao da maconha aborda os pontos de seguranca publica, dentre outros, com argumentos a favor e contra em cada ponto) - isso implica que os conjuntos tem o mesmo tamanho

# %% [markdown]
# ### WEAT for documents (paragraph level, infer about the document's stance)

# %% [raw]
# * TODO: dividir a tabela por casos de pro-con e verificar se há diferencas

# %%
# mean distance of each paragraph to each attribute (argument - con/pro) set
sim_paragraph_args = wmd_df.groupby(["paragraph","topic","title","source","arg_orient","source_stance"]).wmd_norm.agg(['mean']).reset_index()
sim_paragraph_args = sim_paragraph_args.rename(columns={"mean":"mean_dist"})

# difference of distance of each paragraph to the attribute sets
con_args = sim_paragraph_args[sim_paragraph_args.arg_orient == "Con"]
pro_args = sim_paragraph_args[sim_paragraph_args.arg_orient == "Pro"]
sim_paragraph_args = pro_args.merge(con_args, on=["paragraph","topic","title","source","source_stance"]).drop(columns=["arg_orient_x", "arg_orient_y"])
sim_paragraph_args = sim_paragraph_args.rename(columns={"mean_dist_x":"pro_dist","mean_dist_y":"con_dist"})
sim_paragraph_args["diff_dist"] = sim_paragraph_args.pro_dist - sim_paragraph_args.con_dist

# %%
cons_art = sim_paragraph_args[(sim_paragraph_args.source == "conservapedia") & (sim_paragraph_args.topic == "Abortion")]
ratio_art = sim_paragraph_args[(sim_paragraph_args.source == "rationalwiki") & (sim_paragraph_args.topic == "Abortion")]

# %%
from mlxtend.evaluate import permutation_test

sources = sim_paragraph_args.source.unique()
topics = sim_paragraph_args.topic.unique()

significance_test_array = []

for topic in topics:
    conservapedia = sim_paragraph_args[(sim_paragraph_args.source == sources[1]) & (sim_paragraph_args.topic == topic)]
    ratiowiki = sim_paragraph_args[(sim_paragraph_args.source == sources[0]) & (sim_paragraph_args.topic == topic)]

    p_value = permutation_test(conservapedia.diff_dist, ratiowiki.diff_dist,
                           method='approximate', num_rounds=1000)
    
    interpret = "cons-pro x rwiki-con"
    if conservapedia.diff_dist.mean() > ratiowiki.diff_dist.mean():
        interpret = "cons-con x rwiki-pro"
    
    groundtruth = "cons-" + conservapedia.source_stance.iloc[0] + " x ratiowiki-" + ratiowiki.source_stance.iloc[0]
    
    significance_test_array.append([topic, p_value, interpret, groundtruth, conservapedia.diff_dist.mean(), ratiowiki.diff_dist.mean()])
    
significance_test_df = pd.DataFrame(significance_test_array, columns=['topic', 'p_value', 'res_interpretation', 'ground_truth','cons_mean_dif', 'rwiki_mean_dif'])

# %%
significance_test_df
# Out:
#                   topic  p_value    res_interpretation  \
# 0      Health Care Form    0.405  cons-con x rwiki-pro
# 1          Prostitution    0.015  cons-con x rwiki-pro
# 2              Iraq War    0.001  cons-pro x rwiki-con
# 3           Gun Control    0.463  cons-con x rwiki-pro
# 4              Abortion    0.205  cons-pro x rwiki-con
# 5         Death Penalty    0.047  cons-pro x rwiki-con
# 6          Minimum Wage    0.514  cons-pro x rwiki-con
# 7        Climate Change    0.033  cons-con x rwiki-pro
# 8             Marijuana    0.000  cons-pro x rwiki-con
# 9            Euthanasia    0.559  cons-pro x rwiki-con
# 10          Video Games    0.000  cons-con x rwiki-pro
# 11  Corporal Punishment    0.159  cons-con x rwiki-pro
# 12                 GMOs    0.003  cons-con x rwiki-pro
# 13       Net Neutrality    0.050  cons-con x rwiki-pro
# 14      School Vouchers    0.091  cons-pro x rwiki-con
#
#                   ground_truth  cons_mean_dif  rwiki_mean_dif
# 0    cons-Con x ratiowiki-Pro*      -0.009929       -0.012056
# 1    cons-Con x ratiowiki-Pro*       0.015388       -0.001645
# 2     cons-Pro x ratiowiki-Con      -0.006217        0.000850
# 3     cons-Con x ratiowiki-Pro       0.026030        0.020387
# 4     cons-Con x ratiowiki-Pro      -0.009452       -0.005178
# 5     cons-Pro x ratiowiki-Con       0.002700        0.007061
# 6    cons-Con x ratiowiki-Pro*      -0.009455       -0.005851
# 7   cons-Con- x ratiowiki-Pro-       0.002936       -0.004877
# 8     cons-Con x ratiowiki-Pro       0.011054        0.032291
# 9    cons-Con x ratiowiki-Pro*       0.013388        0.016243
# 10  cons-Con- x ratiowiki-Pro-       0.019632        0.009818
# 11    cons-Con x ratiowiki-Con       0.022073       -0.008680
# 12  cons-Con* x ratiowiki-Pro*       0.066395        0.019187
# 13    cons-Con x ratiowiki-Pro       0.016650       -0.004410
# 14  cons-Con* x ratiowiki-Pro*      -0.003801        0.017875

# %% [markdown]
# ### WEAT for documents (document level, infer about the source's stance)

# %% [markdown]
# ###### Toy example

# %%
fake_data = {'content':["pa1","pa2","pa1","pa2","pa1","pa2","pa1","pa2","pa1","pa2"],
             'pro_con':["c1","c1","c2","c2","p1","p1","p2","p2","p3","p3"],
             'source':["con","con","con","con","con","con","con","con","con","con"],
             'topic':["A","A","A","A","A","A","A","A","A","A"],
             'wmd_sim':[0.8, 0.8, 0.9, 0.7, 0.6, 0.8, 0.8, 0.9, 0.7, 0.6]} 

fake_data_2 = {'content':["pa1","pa2","pa3","pa1","pa2","pa3","pa1","pa2","pa3","pa1","pa2","pa3","pa1","pa2","pa3"],
             'pro_con':["c1","c1","c1","c2","c2","c2","p1","p1","p1","p2","p2","p2","p3","p3","p3"],
             'source':["rat","rat","rat","rat","rat","rat","rat","rat","rat","rat","rat","rat","rat","rat","rat"],
             'topic':["A","A","A","A","A","A","A","A","A","A","A","A","A","A","A"],
             'wmd_sim':[0.8, 0.8, 0.9, 0.7, 0.6, 0.8, 0.8, 0.9, 0.7, 0.6, 0.8, 0.8, 0.9, 0.7, 0.6]} 

fake_data_3 = {'content':["pa1","pa2","pa1","pa2","pa1","pa2","pa1","pa2","pa1","pa2","pa1","pa2","pa3","pa1","pa2","pa3","pa1","pa2","pa3","pa1","pa2","pa3","pa1","pa2","pa3"],
             'pro_con':["Con 1","Con 1","Con 2","Con 2","Pro 1","Pro 1","Pro 2","Pro 2","Pro 3","Pro 3","Con 1","Con 1","Con 1","Con 2","Con 2","Con 2","Pro 1","Pro 1","Pro 1","Pro 2","Pro 2","Pro 2","Pro 3","Pro 3","Pro 3"],
             'source':["con","con","con","con","con","con","con","con","con","con","rat","rat","rat","rat","rat","rat","rat","rat","rat","rat","rat","rat","rat","rat","rat"],
             'topic':["A","A","A","A","A","A","A","A","A","A","A","A","A","A","A","A","A","A","A","A","A","A","A","A","A"],
             'wmd_sim':[0.8, 0.8, 0.9, 0.7, 0.6, 0.8, 0.8, 0.9, 0.7, 0.6,0.8, 0.8, 0.9, 0.7, 0.6, 0.8, 0.8, 0.9, 0.7, 0.6, 0.8, 0.8, 0.9, 0.7, 0.6]} 

fake_wmd_df = pd.DataFrame(fake_data_3)
